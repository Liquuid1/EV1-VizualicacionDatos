# %% [markdown]
# # 1) Entender el negocio
#
# > En esta sección se debe explicar los desafios del proyecto, las decisiones tomadas y los KPIs clave para el proyecto. Tambien sera conveniente incluir los objetivos generales y especificos de esta iteración de la evaluación.
# > El resultado de esta sección debe ser definir correctamente los objetivos y tamiben definir los KPIs de analisis.

# %% [markdown]
# # 2) Preparar los datos
#
# > En esta parte se necesita integrar y limpiar los data sets de peliculas y series, es importante unificar los formatos, manejar correctamente valores faltantes y duplicados, estanrazar datos de paises, generos e idiomas, calcular metricas derivada
# > El resultado de esta sección debe ser contar con datos confiables y listos para analizar

# %% [markdown]
# # 3) Explorar y analizar
#
# > En esta sección debemos realizar el EDA en base a los datos preparados en el paso anterior, es importantes descubrir patrones, tendencias y oportunidades, algunos ejemplo de analisis sugeridos son los siguientes:
# > * Desempeño por genero
# > * Ingresos vs Rating
# > * Contenidos por pais
# > * Duración vs popularidad
# > * Clasificación por edad
# > * Evolución en el tiempo
# > Resultado: Hallazgos clave que responden las preguntas del negocio.

# %% [markdown]
# # 4) Diseñar la visualización
#
# > En esta parte dice algo de duseñar un dashboard interactivo y claro, pero en la siguiente sección tambien habla de construir el dashboard, me imagino que esta parte se tiene que diseñar el dashboard a nivel conceptual, ver que es lo que tendra el dashboard, que graficos mostrara, nivel de interactividad y esas cosas, tiene que aplicar los siguientes principios:
#
# > * Simplicidad
# > * Enfoque en lo importante
# > * Jerarquia visual
# > * Consistencia de colores
# > * Interactividad
# > * Contexto y storytelling
#
# > Resultado Dashboard entendible, atractivo y enfocado en decisiones.
#
#
# > RECORDAD: los problemas de esta etapa de la evaluación son los siguientes
# > 1) No existe una visión consolidada del catagolo disponible (Esto se tendra que resolver con el dashboard interactivo)
# > 2) No es posible identificar rapidamente que generos presentan mayor popularidad (Incluir este problema en el EDA)
# > 3) Las decisiones de adquisiciones de nuevos contenidos se realizan utilizando información parcial (Preparar un analisis en el EDA que ayude a resolver esto)
# > 4) No existe una forma simple de comparar paises productores (Esto hay que resolverlo en el dashboard interactivo)
# > 5) La Gerencia de Marketing no dispone de información consolidada para identificar qué contenidos deberían priorizarse en campañas
# promocionales ni qué segmentos del catálogo presentan mayor potencial de posicionamiento.
# > 6) La Gerencia de Adquisición y Gestión de Contenidos requiere comprender qué características poseen los contenidos mejor
# evaluados y con mayor popularidad para orientar futuras decisiones de adquisición, renovación y posicionamiento estratégico del
# catálogo audiovisual.
# > 7) Los dashboards existentes presentan problemas de diseño, exceso de información y poca interacción.

# %% [markdown]
# # 5) Construir el dashboard
#
# > Desarrollar el dashboard en la plataforma definida, en este caso quizá lo hagamos en python

# %% [markdown]
# # 6) Interpretar y comunicar
#
# > En esta parte es importante generar los insights y contar la historia de los datos con claridad y foco en el negocio.

# %% [markdown]
# # 7) Recomendar y tomar decisiones
#
# > Agrupar las conclusiones extraidas en los pasos anteriores para recomendar cursos de acción para el futuro a la luz de los insights encontrados.
